# %% [markdown]
# # Phase 01: Frame Extraction
#
# 이 노트북은 CCTV 비디오 파일로부터 지정된 FPS로 프레임을 추출하고 데이터를 탐색합니다.

# %%
import os
import sys
from pathlib import Path

# 부모 디렉토리를 path에 추가
sys.path.append(str(Path(os.getcwd()).parent))

from src.video_utils import load_config, load_videos_from_config, print_video_summary

# %%
# 설정 파일 로딩 및 요약 출력
config = load_config("../configs/config.yaml")
print_video_summary(config)
